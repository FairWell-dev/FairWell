# %% [markdown]
# # NYC Subway Time Series Classification
# Problem: Predicting whether traffic of passengers in a neighborhood at a specific point in time will be 'High' or 'Low'

# %% [markdown]
# #### Import Libraries & Dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from imblearn.under_sampling import RandomUnderSampler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('drive/MyDrive/PyTorch Hackathon 2021/dataset/baseline_binned.csv')

# %%
df.head()
# Out:
#   Neighborhood        Datetime  ...  ConnectingLine_6  binary_target
# 0      Astoria   1/4/2020 0:00  ...                 0              0
# 1      Astoria   1/4/2020 4:00  ...                 0              0
# 2      Astoria   1/4/2020 8:00  ...                 0              0
# 3      Astoria  1/4/2020 12:00  ...                 0              0
# 4      Astoria  1/4/2020 16:00  ...                 0              0
#
# [5 rows x 69 columns]

# %%
categorical_features = ['Neighborhood']

numerical_features = ['Area (in sq miles)',
                      'Car-free commute (% of commuters)',
                      'Disabled population',
                      'Foreign-born population',
                      'Mean travel time to work (minutes)',
                      'Median household income (2018$)',
                      'Median rent, all (2018$)',
                      'num_of_stations',
                      'Percent Asian', 
                      'Percent Hispanic', 
                      'Percent black', 
                      'Percent white',
                      'Population', 
                      'Population density (1,000 persons per square mile)',
                      'Poverty rate', 
                      'Public housing (% of rental units)',
                      'Rental vacancy rate',
                      'Residential units within 12 mile of a subway station',
                      'Serious crime rate (per 1,000 residents)',
                      'Severely rent-burdened households', 
                      'Unemployment rate']

stations = ['Division_BMT','Division_IND', 'Division_IRT', 'Structure_At Grade',
            'Structure_Elevated', 'Structure_Open Cut', 'Structure_Subway',
            'Structure_Viaduct', 'Borough_Bk', 'Borough_Bx', 'Borough_M',
            'Borough_Q', 'ConnectingLine_N', 'ConnectingLine_Q', 'ConnectingLine_R',
            'ConnectingLine_D', 'ConnectingLine_B',
            'ConnectingLine_F', 'ConnectingLine_M', 'ConnectingLine_A',
            'ConnectingLine_C', 'ConnectingLine_E', 'ConnectingLine_S',
            'ConnectingLine_J', 'ConnectingLine_Z', 'ConnectingLine_1',
            'ConnectingLine_2', 'ConnectingLine_3', 'ConnectingLine_L',
            'ConnectingLine_G', 'ConnectingLine_5', 'ConnectingLine_4',
            'ConnectingLine_7', 'ConnectingLine_6']

time = ["day_of_week", "day", "hour"]

feature_list = categorical_features + time + numerical_features + stations

label = ['binary_target']

# %%
df.shape
# Out:
# (27846, 69)

# %% [markdown]
# ### Undersampling

# %%
neighborhood_df = df.groupby('Neighborhood').first().drop(columns=['Datetime','binary_target'])

# %%
neighborhood_df
# Out:
#                                       Area (in sq miles)  ...  ConnectingLine_6
# Neighborhood                                              ...
# Astoria                                         5.151129  ...                 0
# Bay Ridge/Dyker Heights                         3.846978  ...                 0
# Bedford Stuyvesant                              2.298172  ...                 0
# Bensonhurst                                     3.695691  ...                 0
# Borough Park                                    3.144979  ...                 0
# Brownsville                                     2.593279  ...                 0
# Bushwick                                        2.535632  ...                 0
# Central Harlem                                  1.430087  ...                 0
# Clinton/Chelsea                                 3.073690  ...                 0
# Coney Island                                    3.436873  ...                 0
# Crown Heights/Prospect Heights                  2.221395  ...                 0
# East Flatbush                                   3.078835  ...                 0
# East Harlem                                     2.320362  ...                 1
# East New York/Starrett City                     6.064296  ...                 0
# Elmhurst/Corona                                 3.603473  ...                 0
# Financial District                              2.898482  ...                 1
# Flatbush/Midwood                                2.909402  ...                 0
# Flatlands/Canarsie                             12.684529  ...                 0
# Flushing/Whitestone                            11.777466  ...                 0
# Fordham/University Heights                      1.510580  ...                 0
# Fort Greene/Brooklyn Heights                    3.113655  ...                 0
# Greenpoint/Williamsburg                         4.130489  ...                 0
# Highbridge/Concourse                            1.996133  ...                 0
# Hillcrest/Fresh Meadows                         7.467773  ...                 0
# Hunts Point/Longwood                            4.901473  ...                 1
# Jackson Heights                                 4.182359  ...                 0
# Jamaica/Hollis                                  9.303396  ...                 0
# Kew Gardens/Woodhaven                           4.744019  ...                 0
# Kingsbridge Heights/Bedford                     1.568743  ...                 0
# Lower East Side/Chinatown                       1.744457  ...                 1
# Morningside Heights/Hamilton                    1.685465  ...                 0
# Morris Park/Bronxdale                           3.813206  ...                 1
# Morrisania/Crotona                              4.373837  ...                 0
# Park Slope/Carroll Gardens                      4.007207  ...                 0
# Parkchester/Soundview                           4.422941  ...                 1
# Queens Village                                 19.696792  ...                 0
# Rego Park/Forest Hills                          2.804764  ...                 0
# Ridgewood/Maspeth                               7.317757  ...                 0
# Riverdale/Fieldston                             3.421208  ...                 0
# Rockaway/Broad Channel                         11.275508  ...                 0
# Sheepshead Bay                                  4.329873  ...                 0
# South Crown Heights/Lefferts Gardens            1.707572  ...                 0
# South Ozone Park/Howard Beach                   6.137577  ...                 0
# Stuyvesant Town/Turtle Bay                      1.621603  ...                 1
# Sunset Park                                     4.009222  ...                 0
# Throgs Neck/Co-op City                          9.294672  ...                 1
# Upper East Side                                 1.987189  ...                 1
# Upper West Side                                 2.963290  ...                 0
# Washington Heights/Inwood                       2.929401  ...                 0
# Williamsbridge/Baychester                       6.744888  ...                 0
# Woodside/Sunnyside                              6.000987  ...                 0
#
# [51 rows x 66 columns]

# %%
neighborhood_df = neighborhood_df.reset_index()
neighborhood_df.shape
# Out:
# (51, 67)

# %%
sensitive_col = 'Privileged: Lower Foreign-born population'

# %%
neighborhood_df[sensitive_col].hist()

# %%
neighborhood_df[sensitive_col].value_counts()
# Out:
# 1    26
# 0    25
# Name: Privileged: Lower Foreign-born population, dtype: int64

# %%
X = neighborhood_df.drop(columns=[sensitive_col])
y = neighborhood_df[sensitive_col]
undersampler = RandomUnderSampler()
X_, y_ = undersampler.fit_resample(X, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
X_.shape
# Out:
# (50, 66)

# %%
concat = np.concatenate([X_, y_.reshape(-1, 1)],axis=1)
column_names = neighborhood_df.columns.tolist()
column_names.append(column_names.pop(column_names.index(sensitive_col)))
neighborhood_df_undersampled = pd.DataFrame(data=concat, columns=column_names)

# %%
neighborhood_df_undersampled[sensitive_col].hist()

# %%
drop_neighborhood_list = list(set(neighborhood_df['Neighborhood'].unique()) - set(neighborhood_df_undersampled['Neighborhood'].unique()))
print(drop_neighborhood_list)
# Out:
# ['Borough Park']

# %%
df_undersampled = df[~df['Neighborhood'].isin(drop_neighborhood_list)]

# %%
df_undersampled.shape
# Out:
# (27300, 69)

# %%
df_undersampled
# Out:
#        Neighborhood            Datetime  ...       day  hour
# 0                 0 2020-01-04 00:00:00  ...  0.000000   0.0
# 1                 0 2020-01-04 04:00:00  ...  0.000000   0.2
# 2                 0 2020-01-04 08:00:00  ...  0.000000   0.4
# 3                 0 2020-01-04 12:00:00  ...  0.000000   0.6
# 4                 0 2020-01-04 16:00:00  ...  0.000000   0.8
# ...             ...                 ...  ...       ...   ...
# 27841            49 2020-06-30 04:00:00  ...  0.962963   0.2
# 27842            49 2020-06-30 08:00:00  ...  0.962963   0.4
# 27843            49 2020-06-30 12:00:00  ...  0.962963   0.6
# 27844            49 2020-06-30 16:00:00  ...  0.962963   0.8
# 27845            49 2020-06-30 20:00:00  ...  0.962963   1.0
#
# [27300 rows x 72 columns]

# %%
df_undersampled.to_csv('drive/MyDrive/PyTorch Hackathon 2021/dataset/undersampling_1103.csv')

# %% [markdown]
# ### Data Preparation
#
# *   Generation of time-based features (day, day of week, hour)
# *   Min-max transformation of numerical features (fit on train and transform on both)
# *   Label encoding of categorical feature (Neighborhood) - for input into Embedding Layer

# %%
df = df_undersampled

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])
df['day_of_week'] = df['Datetime'].dt.dayofweek
df['day'] = df['Datetime'].dt.day
df['hour'] = df['Datetime'].dt.hour
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

columns_to_minmax = numerical_features + time

scaler = MinMaxScaler().fit(df[[*columns_to_minmax]])
df[[*columns_to_minmax]] = scaler.transform(df[[*columns_to_minmax]])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
# to feed into embedding layer

columns_to_le = categorical_features

le = LabelEncoder()
df[[*columns_to_le]] = le.fit_transform(df[[*columns_to_le]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
df.columns
# Out:
# Index(['Neighborhood', 'Datetime', 'Area (in sq miles)',
#        'Car-free commute (% of commuters)', 'Disabled population',
#        'Foreign-born population', 'Mean travel time to work (minutes)',
#        'Median household income (2018$)', 'Median rent, all (2018$)',
#        'num_of_stations', 'Percent Asian', 'Percent Hispanic', 'Percent black',
#        'Percent white', 'Population',
#        'Population density (1,000 persons per square mile)', 'Poverty rate',
#        'Public housing (% of rental units)', 'Rental vacancy rate',
#        'Residential units within 12 mile of a subway station',
#        'Serious crime rate (per 1,000 residents)',
#        'Severely rent-burdened households', 'Unemployment rate',
#        'Privileged: Higher Percent white',
#        'Privileged: Higher Median household income (2018$)',
#        'Privileged: Lower Percent Asian', 'Privileged: Lower Percent Hispanic',
#        'Privileged: Lower Percent black',
#        'Privileged: Lower Foreign-born population',
#        'Privileged: Lower Poverty rate', 'Privileged: Lower Unemployment rate',
#        'Privileged: Lower Severely rent-burdened households',
#        'Privileged: Lower Serious crime rate (per 1,000 residents)',
#        'Privileged: Lower Disabled population', 'Division_BMT', 'Division_IND',
#        'Division_IRT', 'Structure_At Grade', 'Structure_Elevated',
#        'Structure_Open Cut', 'Structure_Subway', 'Structure_Viaduct',
#        'Borough_Bk', 'Borough_Bx', 'Borough_M', 'Borough_Q',
#        'ConnectingLine_N', 'ConnectingLine_Q', 'ConnectingLine_R',
#        'ConnectingLine_D', 'ConnectingLine_B', 'ConnectingLine_F',
#        'ConnectingLine_M', 'ConnectingLine_A', 'ConnectingLine_C',
#        'ConnectingLine_E', 'ConnectingLine_S', 'ConnectingLine_J',
#        'ConnectingLine_Z', 'ConnectingLine_1', 'ConnectingLine_2',
#        'ConnectingLine_3', 'ConnectingLine_L', 'ConnectingLine_G',
#        'ConnectingLine_5', 'ConnectingLine_4', 'ConnectingLine_7',
#        'ConnectingLine_6', 'binary_target', 'day_of_week', 'day', 'hour'],
#       dtype='object')

# %% [markdown]
# ### Timeseries Dataset & Data Loader
#
# *   Train-Test split for timeseries data based on time, to avoid look ahead bias.

# %%
def timeseries_train_test_split(df, time_column, val_size=0.2, test_size=0.1, drop_time_col=False):
    """
    Train-Test split for Timeseries data based on time, to avoid look ahead bias.
    :param df: Pandas df
    :param time_column: Column name of timestamp, to generate split by
    :param val_size: Size of validation dataset
    :param test_size: Size of test dataset
    :param drop_time_col: Boolean option of dropping time column from generated train/val/test dataframes, default False
    :return train_df: Pandas dataframe for training data
    :return val_df: Pandas dataframe for validation data
    :retrun test_df: Pandas dataframe for test data
    """
    timesteps = df[time_column].unique()
    length = len(timesteps)
    train_timesteps = timesteps[: int(np.ceil(length*(1-val_size-test_size)))]
    val_timesteps = timesteps[int(np.ceil(length*(1-val_size-test_size))) : int(np.ceil(length*(1-test_size)))]
    test_timesteps = timesteps[int(np.ceil(length*(1-test_size))):]

    train_df = df[df[time_column].isin(train_timesteps)]
    val_df = df[df[time_column].isin(val_timesteps)]
    test_df = df[df[time_column].isin(test_timesteps)]

    if drop_time_col:
      train_df = train_df.drop(time_column, axis=1)
      val_df = val_df.drop(time_column, axis=1)
      test_df = test_df.drop(time_column, axis=1)

    return train_df, val_df, test_df

# %%
train_df, val_df, test_df = timeseries_train_test_split(df, 'Datetime', val_size=0.2, test_size=0.1, drop_time_col=True)

# %%
train_df.shape, val_df.shape, test_df.shape
# Out:
# ((19150, 71), (5450, 71), (2700, 71))

# %%
def df_to_tensor(df):
    x1 = np.array(df[[*categorical_features]]).astype(int) 
    x2 = np.array(df[[*(time + numerical_features + stations)]])
    y = np.array(df[label])

    x1_ts = torch.Tensor(x1).type(torch.LongTensor)
    x2_ts = torch.Tensor(x2)
    y_ts = torch.Tensor(y)

    return x1_ts, x2_ts, y_ts

# %%
x1_train_ts, x2_train_ts, y_train_ts = df_to_tensor(train_df)
x1_val_ts, x2_val_ts, y_val_ts = df_to_tensor(val_df)
x1_test_ts, x2_test_ts, y_test_ts = df_to_tensor(test_df)

# %%
x1_train_ts.shape, x2_train_ts.shape, y_train_ts.shape, x1_val_ts.shape, x2_val_ts.shape, y_val_ts.shape, x1_test_ts.shape, x2_test_ts.shape, y_test_ts.shape
# Out:
# (torch.Size([19150, 1]),
#  torch.Size([19150, 58]),
#  torch.Size([19150, 1]),
#  torch.Size([5450, 1]),
#  torch.Size([5450, 58]),
#  torch.Size([5450, 1]),
#  torch.Size([2700, 1]),
#  torch.Size([2700, 58]),
#  torch.Size([2700, 1]))

# %%
from torch.utils.data import TensorDataset,DataLoader
train_set = TensorDataset(x1_train_ts, x2_train_ts, y_train_ts)
val_set = TensorDataset(x1_val_ts,x2_val_ts,y_val_ts)

train_loader = DataLoader(train_set, batch_size = 32, shuffle = False)
val_loader = DataLoader(val_set, batch_size = 32, shuffle = False)

# %%
### save testing dataset as df
test_df.to_csv('drive/MyDrive/PyTorch Hackathon 2021/models/2. undersampling/undersampling_1103.csv', index=False)

# %% [markdown]
# ### Model Architecture
#
#  MultiInputNet - multiple input neural network architecture, to treat each type of feature differently

# %%
from torch import nn,optim
class  MultiInputNet(nn.Module):
    """Multiple input model - FFN + an embedding layer for neighborhood """
    def __init__(self, x1_size, x2_size, vocab_size, embed_dim, hidden_size_1, hidden_size_2, num_classes):
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size,embed_dim)
        self.fc1 = nn.Linear(x2_size, hidden_size_1)
        self.relu = nn.ReLU() 
        self.fc2 = nn.Linear(hidden_size_1 + embed_dim, hidden_size_2)
        self.relu = nn.ReLU() 
        self.fc3 = nn.Linear(hidden_size_2,num_classes)

    def forward(self, x1, x2):
        x1 = self.embeddings(x1)
        x1 = torch.squeeze(x1)
        x2 = self.fc1(x2)
        x2 = self.relu(x2)
        x = torch.cat((x1, x2),dim=1)
        x = self.fc2(x)
        x = self.relu(x)
        x = torch.sigmoid(self.fc3(x))
        return x

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

num_classes = 1 # binary

x1_size = x1_train_ts.shape[1]
x2_size = x2_train_ts.shape[1]

# Embedding
vocab_size = len(df['Neighborhood'].unique())
embed_dim = hidden_size_1 = 10

# FFN
hidden_size_2 = 10

base_model = MultiInputNet(x1_size,
                          x2_size,
                          vocab_size,
                          embed_dim,
                          hidden_size_1,
                          hidden_size_2,
                          num_classes).to(device)
print(base_model)
# Out:
# MultiInputNet(
#   (embeddings): Embedding(50, 10)
#   (fc1): Linear(in_features=58, out_features=10, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=20, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=1, bias=True)
# )

# %% [markdown]
# ### Model Training

# %%
NUM_EPOCHS = 100
lr = 0.005
criterion = nn.BCELoss()
optimizer = optim.SGD(base_model.parameters(), lr=lr)

# %%
def make_train_step(net, criterion, optimizer):

  def train_step(inputs, labels):

    optimizer.zero_grad()
    outputs = net(*inputs)

    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    return loss.item()
    
  return train_step


def make_val_step(net, criterion):

  def val_step(x, y):
    net.eval()

    y_hat = net(*x)
    val_loss = criterion(y_hat, y)

    return val_loss.item()

  return val_step

# %%
train_step = make_train_step(base_model, criterion, optimizer)
val_step = make_val_step(base_model, criterion)

losses = []
val_losses = []

for epoch in range(NUM_EPOCHS):
  running_loss = 0.0
  running_val_loss = 0.0

  for i, (x1, x2, y) in enumerate(train_loader):
    x1 = x1.to(device)
    x2 = x2.to(device)
    y = y.to(device)

    loss = train_step([x1, x2], y)
    running_loss += loss

  with torch.no_grad():
    for i, (x1, x2, y) in enumerate(val_loader):
        x1 = x1.to(device)
        x2 = x2.to(device)
        y = y.to(device)

        val_loss = val_step([x1, x2], y)
        running_val_loss += val_loss

  epoch_loss = running_loss / len(train_loader)
  epoch_val_loss = running_val_loss / len(val_loader)
  print('Epoch: %d, training loss: %.3f, val loss: %.3f'%(epoch+1,epoch_loss,epoch_val_loss))

  losses.append(epoch_loss)
  val_losses.append(epoch_val_loss)

print('Finished Training')
# Out:
# Epoch: 1, training loss: 0.688, val loss: 0.685
# Epoch: 2, training loss: 0.679, val loss: 0.677
# Epoch: 3, training loss: 0.668, val loss: 0.666
# Epoch: 4, training loss: 0.652, val loss: 0.649
# Epoch: 5, training loss: 0.630, val loss: 0.627
# Epoch: 6, training loss: 0.601, val loss: 0.601
# Epoch: 7, training loss: 0.566, val loss: 0.571
# Epoch: 8, training loss: 0.528, val loss: 0.539
# Epoch: 9, training loss: 0.489, val loss: 0.509
# Epoch: 10, training loss: 0.453, val loss: 0.482
# Epoch: 11, training loss: 0.420, val loss: 0.480
# Epoch: 12, training loss: 0.393, val loss: 0.459
# Epoch: 13, training loss: 0.375, val loss: 0.441
# Epoch: 14, training loss: 0.359, val loss: 0.422
# Epoch: 15, training loss: 0.346, val loss: 0.403
# Epoch: 16, training loss: 0.334, val loss: 0.386
# Epoch: 17, training loss: 0.320, val loss: 0.373
# Epoch: 18, training loss: 0.308, val loss: 0.362
# Epoch: 19, training loss: 0.298, val loss: 0.354
# Epoch: 20, training loss: 0.289, val loss: 0.348
# Epoch: 21, training loss: 0.282, val loss: 0.342
# Epoch: 22, training loss: 0.276, val loss: 0.338
# Epoch: 23, training loss: 0.270, val loss: 0.334
# Epoch: 24, training loss: 0.265, val loss: 0.332
# Epoch: 25, training loss: 0.261, val loss: 0.330
# Epoch: 26, training loss: 0.258, val loss: 0.329
# Epoch: 27, training loss: 0.256, val loss: 0.328
# Epoch: 28, training loss: 0.254, val loss: 0.328
# Epoch: 29, training loss: 0.251, val loss: 0.328
# Epoch: 30, training loss: 0.250, val loss: 0.328
# Epoch: 31, training loss: 0.248, val loss: 0.328
# Epoch: 32, training loss: 0.247, val loss: 0.328
# Epoch: 33, training loss: 0.246, val loss: 0.327
# Epoch: 34, training loss: 0.245, val loss: 0.327
# Epoch: 35, training loss: 0.244, val loss: 0.326
# Epoch: 36, training loss: 0.243, val loss: 0.325
# Epoch: 37, training loss: 0.242, val loss: 0.324
# Epoch: 38, training loss: 0.241, val loss: 0.323
# Epoch: 39, training loss: 0.240, val loss: 0.322
# Epoch: 40, training loss: 0.239, val loss: 0.321
# Epoch: 41, training loss: 0.239, val loss: 0.320
# Epoch: 42, training loss: 0.238, val loss: 0.319
# Epoch: 43, training loss: 0.237, val loss: 0.318
# Epoch: 44, training loss: 0.237, val loss: 0.317
# Epoch: 45, training loss: 0.236, val loss: 0.317
# Epoch: 46, training loss: 0.235, val loss: 0.316
# Epoch: 47, training loss: 0.235, val loss: 0.315
# Epoch: 48, training loss: 0.234, val loss: 0.314
# Epoch: 49, training loss: 0.233, val loss: 0.313
# Epoch: 50, training loss: 0.233, val loss: 0.312
# Epoch: 51, training loss: 0.232, val loss: 0.311
# Epoch: 52, training loss: 0.231, val loss: 0.311
# Epoch: 53, training loss: 0.231, val loss: 0.310
# Epoch: 54, training loss: 0.230, val loss: 0.309
# Epoch: 55, training loss: 0.229, val loss: 0.308
# Epoch: 56, training loss: 0.229, val loss: 0.307
# Epoch: 57, training loss: 0.228, val loss: 0.306
# Epoch: 58, training loss: 0.227, val loss: 0.305
# Epoch: 59, training loss: 0.226, val loss: 0.305
# Epoch: 60, training loss: 0.225, val loss: 0.304
# Epoch: 61, training loss: 0.224, val loss: 0.303
# Epoch: 62, training loss: 0.224, val loss: 0.303
# Epoch: 63, training loss: 0.223, val loss: 0.302
# Epoch: 64, training loss: 0.222, val loss: 0.302
# Epoch: 65, training loss: 0.222, val loss: 0.301
# Epoch: 66, training loss: 0.221, val loss: 0.301
# Epoch: 67, training loss: 0.220, val loss: 0.300
# Epoch: 68, training loss: 0.220, val loss: 0.300
# Epoch: 69, training loss: 0.219, val loss: 0.300
# Epoch: 70, training loss: 0.218, val loss: 0.299
# Epoch: 71, training loss: 0.218, val loss: 0.298
# Epoch: 72, training loss: 0.217, val loss: 0.298
# Epoch: 73, training loss: 0.216, val loss: 0.297
# Epoch: 74, training loss: 0.216, val loss: 0.297
# Epoch: 75, training loss: 0.215, val loss: 0.296
# Epoch: 76, training loss: 0.215, val loss: 0.296
# Epoch: 77, training loss: 0.214, val loss: 0.295
# Epoch: 78, training loss: 0.214, val loss: 0.294
# Epoch: 79, training loss: 0.213, val loss: 0.293
# Epoch: 80, training loss: 0.212, val loss: 0.293
# Epoch: 81, training loss: 0.212, val loss: 0.292
# Epoch: 82, training loss: 0.211, val loss: 0.293
# Epoch: 83, training loss: 0.211, val loss: 0.293
# Epoch: 84, training loss: 0.210, val loss: 0.292
# Epoch: 85, training loss: 0.209, val loss: 0.292
# Epoch: 86, training loss: 0.209, val loss: 0.291
# Epoch: 87, training loss: 0.208, val loss: 0.290
# Epoch: 88, training loss: 0.208, val loss: 0.290
# Epoch: 89, training loss: 0.207, val loss: 0.290
# Epoch: 90, training loss: 0.207, val loss: 0.290
# Epoch: 91, training loss: 0.206, val loss: 0.289
# Epoch: 92, training loss: 0.206, val loss: 0.289
# Epoch: 93, training loss: 0.205, val loss: 0.289
# Epoch: 94, training loss: 0.205, val loss: 0.289
# Epoch: 95, training loss: 0.205, val loss: 0.288
# Epoch: 96, training loss: 0.204, val loss: 0.288
# Epoch: 97, training loss: 0.204, val loss: 0.287
# Epoch: 98, training loss: 0.203, val loss: 0.287
# Epoch: 99, training loss: 0.203, val loss: 0.287
# Epoch: 100, training loss: 0.202, val loss: 0.286
# Finished Training

# %%
plt.plot(losses)
plt.plot(val_losses)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Val Loss'])
plt.show()

# %%
from torch import jit
# exporting model to Torchscript using tracing
# https://discuss.pytorch.org/t/how-to-load-using-torch-load-without-source-class-using-which-model-was-created/75302
PATH = 'drive/My Drive/PyTorch Hackathon 2021/models/2. undersampling/undersampling_1103.pt'
net_trace = jit.trace(base_model, (x1, x2))
jit.save(net_trace, PATH)

# %% [markdown]
# ### Model Inference & Eval

# %%
model = torch.jit.load(PATH)

# %%
with torch.no_grad():
  model.eval()
  pred_proba = model(x1_test_ts, x2_test_ts)

# %%
# get y_test and y_pred np arrays for sklearn metric eval
y_pred = [1 if i >= 0.5 else 0 for i in pred_proba]
y_test = y_test_ts.detach().cpu().numpy()

# %%
from sklearn.metrics import accuracy_score, balanced_accuracy_score,confusion_matrix,roc_auc_score,classification_report
print(accuracy_score(y_test, y_pred))
print(balanced_accuracy_score(y_test, y_pred))
# Out:
# 0.8507407407407407
# 0.850317242879962

# %%
roc_auc_score(y_test, pred_proba)
# Out:
# 0.9421814067703758

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1090,  209],
#        [ 194, 1207]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.84      0.84      1299
#          1.0       0.85      0.86      0.86      1401
#
#     accuracy                           0.85      2700
#    macro avg       0.85      0.85      0.85      2700
# weighted avg       0.85      0.85      0.85      2700

# %%
pred_df = test_df
pred_df['binary_target_prediction'] = y_pred

# %%
pred_df
# Out:
#        Neighborhood  Area (in sq miles)  ...  hour  binary_target_prediction
# 492               0            0.203706  ...   0.0                         0
# 493               0            0.203706  ...   0.2                         0
# 494               0            0.203706  ...   0.4                         0
# 495               0            0.203706  ...   0.6                         0
# 496               0            0.203706  ...   0.8                         0
# ...             ...                 ...  ...   ...                       ...
# 27841            49            0.250231  ...   0.2                         0
# 27842            49            0.250231  ...   0.4                         0
# 27843            49            0.250231  ...   0.6                         0
# 27844            49            0.250231  ...   0.8                         0
# 27845            49            0.250231  ...   1.0                         0
#
# [2700 rows x 72 columns]

# %%
pred_df.to_csv('drive/MyDrive/PyTorch Hackathon 2021/dataset/pred_csv/pred_undersampling_1103.csv')
